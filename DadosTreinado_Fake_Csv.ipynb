# %% [markdown]
# <a href="https://colab.research.google.com/github/VagnerPereira260175/testecolab/blob/main/DadosTreinado_Fake_Csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
from pandas.io.parsers.readers import read_csv # faz a leitura do data set em formato de csv.
data = read_csv('/content/dadosbitsas (2).csv')

# %%
print(data)

# %%
from pycaret.regression import *
teste = setup(data, target = 'water_spend')

# %%
best = compare_models()
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# lasso                    Lasso Regression  0.2572  0.0871  0.2943 -0.0464
# en                            Elastic Net  0.2572  0.0871  0.2943 -0.0464
# dummy                     Dummy Regressor  0.2572  0.0871  0.2943 -0.0464
# llar         Lasso Least Angle Regression  0.2572  0.0871  0.2943 -0.0464
# ada                    AdaBoost Regressor  0.2611  0.0879  0.2954 -0.0528
# ridge                    Ridge Regression  0.2583  0.0880  0.2957 -0.0563
# lr                      Linear Regression  0.2584  0.0881  0.2958 -0.0575
# lar                Least Angle Regression  0.2584  0.0881  0.2958 -0.0575
# omp           Orthogonal Matching Pursuit  0.2584  0.0881  0.2958 -0.0575
# br                         Bayesian Ridge  0.2586  0.0885  0.2966 -0.0622
# huber                     Huber Regressor  0.2590  0.0887  0.2967 -0.0641
# lightgbm  Light Gradient Boosting Machine  0.2664  0.0946  0.3069 -0.1448
# ...

# %%
print(best)

# %%
evaluate_model(best) # Gera varios tipos de graficos

# %%
plot_model(best, plot = 'residuals')# Gera graficos induvidualmente.

# %%
predictions = predict_model(best, data=data)
predictions.head() # Gera dados atraves do conjunto não utizado no treino

# %%
save_model(best, 'meu_teste')
